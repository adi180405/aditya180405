# %% [markdown]
# 🏠 Project Title: House Price Prediction using Machine Learning
# 📘 Project Description
#
# This project aims to predict the selling price of a house based on various features such as its area, number of bedrooms, bathrooms, and amenities. Using a machine learning regression model, the system learns patterns from historical housing data and estimates property prices for new inputs.
#
# The project integrates a Flask web application that allows users to input house details through a simple form and instantly view the predicted price.

# %% [markdown]
# 🧠 Model Description
# 1. Objective
#
# To build a predictive model that estimates house prices based on multiple independent variables influencing property value.
#
# 2. Input Features (Independent Variables)
#
# The model takes the following features as inputs:
#
# Feature Name	Description	Type
#
# 1) area	Total area of the house in square feet	Numerical
#
# 2) bedrooms	Number of bedrooms in the house	Numerical
#
# 3) bathrooms	Number of bathrooms	Numerical
#
# 4) mainroad	Whether the house has access to the main road (1 = Yes, 0 = No)	Categorical (Binary)
#
# 5) guestroom	Whether a guest room is available (1 = Yes, 0 = No)	Categorical (Binary)
#
# 6) basement	Whether the house has a basement (1 = Yes, 0 = No)	Categorical (Binary)
#
# 7) hotwaterheating	Availability of hot water heating (1 = Yes, 0 = No)	Categorical (Binary)
#
# 8) airconditioning	Availability of air conditioning (1 = Yes, 0 = No)	Categorical (Binary)
#
# 9) parking	Number of parking spots available	Numerical
#
# 10) prefarea	Whether the house is located in a preferred area (1 = Yes, 0 = No)	Categorical (Binary)
#
# 11) furnishingstatus	Furnishing level (0 = Unfurnished, 1 = Semi-furnished, 2 = Furnished)	Categorical
# (Ordinal)
#
# 3. Target Variable (Dependent Variable)
#
# price → The actual price of the house (used for training).

# %% [markdown]
# ⚙️ Model Building Steps
#
# Data Collection
# A dataset containing house features and prices was used.
# (Example: Housing dataset from Kaggle or custom CSV.)
#
# Data Preprocessing
#
# Handled categorical data (encoded as binary/ordinal numbers).
#
# Removed missing or invalid values.
#
# Normalized or scaled numerical features if necessary.
#
# Model Selection
# Various regression algorithms were tested:
#
# Linear Regression
#
# Ridge / Lasso Regression
#
# Decision Tree Regressor
#
# Random Forest Regressor
#
# After evaluation, the Linear Regression model gave an accuracy of approximately 61%, which was found to be the most stable for this dataset.
#
# Model Training
# The dataset was split into:
#
# 80% Training set
#
# 20% Testing set
# The model was trained on the training data using scikit-learn’s fit() method.
#
# Model Evaluation
#
# Metrics used: R² score (accuracy), Mean Squared Error (MSE), and Mean Absolute Error (MAE).
#
# Achieved around 61% accuracy on the test data using Linear Regression.
#
# Model Deployment
#
# The trained model was saved as model.pkl using the pickle library.
#
# A Flask web app was built to provide user input fields and display predictions dynamically.
