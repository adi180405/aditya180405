# %%
import pickle
from flask import Flask, request, render_template
import numpy as np

application = Flask(__name__)
app = application

# Load model and scaler
linear = pickle.load(open('linear.pkl', 'rb'))
standard=pickle.load(open('standard.pkl','rb'))

@app.route('/', methods=['GET', 'POST'])
def predict_datapoint():
    if request.method == 'POST':
        area = float(request.form.get('area'))
        bedrooms = float(request.form.get('bedrooms'))
        bathrooms = float(request.form.get('bathrooms'))
        mainroad = float(request.form.get('mainroad'))
        guestroom = float(request.form.get('guestroom'))
        basement = float(request.form.get('basement'))
        hotwaterheating = float(request.form.get('hotwaterheating'))
        airconditioning = float(request.form.get('airconditioning'))
        parking = float(request.form.get('parking'))
        prefarea=int(request.form.get('prefarea'))
        furnishingstatus=int(request.form.get('furnishingstatus'))

        new_data_scaled = standard.transform([[area,bedrooms,bathrooms,mainroad,guestroom,basement,
       hotwaterheating, airconditioning, parking, prefarea,
       furnishingstatus]])

        result = linear.predict(new_data_scaled)

        return render_template('home.html', results=result[0])
        
    else:
        return render_template('home.html')

if __name__ == "__main__":
    app.run(host='0.0.0.0')
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://10.43.165.156:5000
# Press CTRL+C to quit
# [2025-10-07 10:48:53,322] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "f:\anacoda3\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "f:\anacoda3\Lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "f:\anacoda3\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "f:\anacoda3\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
# ...

# %%
import pickle
from flask import Flask, request, render_template
import numpy as np

application = Flask(__name__)
app = application

# Load model and scaler
linear = pickle.load(open('linear.pkl', 'rb'))
standard=pickle.load(open('standard.pkl','rb'))
@app.route('/', methods=['GET', 'POST'])
def predict_datapoint():
    if request.method == 'POST':
        try:
            # collect numeric data
            area = float(request.form.get('area'))
            bedrooms = float(request.form.get('bedrooms'))
            bathrooms = float(request.form.get('bathrooms'))
            mainroad = int(request.form.get('mainroad'))
            guestroom = int(request.form.get('guestroom'))
            basement = int(request.form.get('basement'))
            hotwaterheating = int(request.form.get('hotwaterheating'))
            airconditioning = int(request.form.get('airconditioning'))
            parking = float(request.form.get('parking'))
            prefarea = int(request.form.get('prefarea'))
            furnishingstatus = int(request.form.get('furnishingstatus'))

            new_data_scaled = standard.transform([[area, bedrooms, bathrooms, mainroad, guestroom, basement,
                hotwaterheating, airconditioning, parking, prefarea, furnishingstatus]])

            result = linear.predict(new_data_scaled)
            return render_template('home.html', results=result[0])
        except Exception as e:
            return render_template('home.html', results=f"Error: {e}")
    else:
        return render_template('home.html')
if __name__ == "__main__":
    app.run(host='0.0.0.0')
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://10.43.165.156:5000
# Press CTRL+C to quit
# [2025-10-07 10:51:48,848] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "f:\anacoda3\Lib\site-packages\flask\app.py", line 1511, in wsgi_app
#     response = self.full_dispatch_request()
#   File "f:\anacoda3\Lib\site-packages\flask\app.py", line 919, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "f:\anacoda3\Lib\site-packages\flask\app.py", line 917, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "f:\anacoda3\Lib\site-packages\flask\app.py", line 902, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)  # type: ignore[no-any-return]
# ...
